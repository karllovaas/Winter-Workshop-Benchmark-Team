# %%
'''
=================================================================
            Jupyter for Testing and Pulling Relevant Data
=================================================================

:::: Data Required for Recreating the Russell Midcap Growth Benchmark :::::
    (1): The universe of stocks. i.e. the Russel 3000 Index over the last five years (best case) or 
         last two years (worst case)
    (2): Market Capitilization over the last five year
    (3): EOD Closing Price of Russel 3000 the last five years 


'''

# %%
'''
=================================================================
            Quick Alpaca Example 
=================================================================
'''
# imports 
import pandas as pd 
from typing import cast
from datetime import datetime
import alpaca.data as adt
from alpaca.data import TimeFrame
from alpaca.trading import (
    TradingClient,
    OrderRequest,
    OrderType,
    OrderSide,
    TimeInForce,
)


API_KEY = 'PKI5OUPA4GGEGNIYHJJBNOPUWM'
API_SECRET = '7xXifaSB8hwMHoJYRw7dPw2nFpAjNcVnBjw64T79Qdyi'
data_client = adt.StockHistoricalDataClient(api_key= API_KEY, secret_key = API_SECRET)
symbols = ["NVDA","MSFT"]
start_date = datetime(2025,1,1)
end_date = datetime(2026,1,1)


bars_request = adt.StockBarsRequest(
        symbol_or_symbols= symbols,
        start = start_date,
        end = end_date,
        timeframe = TimeFrame.Day, #type: ignore
        feed  =adt.DataFeed.SIP,
)

bars = data_client.get_stock_bars(bars_request)
bars = cast(adt.BarSet,bars)
bars = cast(adt.BarSet,bars)
df_day: pd.DataFrame = bars.df 

df_day
# Out:
#                                     open     high       low   close  \
# symbol timestamp
# MSFT   2025-01-02 05:00:00+00:00  425.53  426.070  414.8500  418.58
#        2025-01-03 05:00:00+00:00  421.08  424.030  419.5400  423.35
#        2025-01-06 05:00:00+00:00  428.00  434.320  425.4774  427.85
#        2025-01-07 05:00:00+00:00  429.00  430.650  420.8000  422.37
#        2025-01-08 05:00:00+00:00  423.46  426.970  421.5400  424.56
# ...                                  ...      ...       ...     ...
# NVDA   2025-12-24 05:00:00+00:00  187.94  188.910  186.5900  188.61
#        2025-12-26 05:00:00+00:00  189.92  192.690  188.0000  190.53
#        2025-12-29 05:00:00+00:00  187.71  188.755  185.9100  188.22
#        2025-12-30 05:00:00+00:00  188.24  188.990  186.9300  187.54
#        2025-12-31 05:00:00+00:00  189.57  190.560  186.4900  186.50
#
#                                        volume  trade_count        vwap
# symbol timestamp
# MSFT   2025-01-02 05:00:00+00:00   16896469.0     353076.0  419.698066
#        2025-01-03 05:00:00+00:00   16662943.0     285046.0  422.518088
#        2025-01-06 05:00:00+00:00   20573648.0     372816.0  428.999489
#        2025-01-07 05:00:00+00:00   18139065.0     299265.0  424.525247
#        2025-01-08 05:00:00+00:00   15054575.0     249660.0  424.510336
# ...                                       ...          ...         ...
# NVDA   2025-12-24 05:00:00+00:00   65528545.0    1265927.0  187.931535
#        2025-12-26 05:00:00+00:00  139740292.0    2035094.0  191.348402
#        2025-12-29 05:00:00+00:00  120006103.0    1952947.0  187.376403
#        2025-12-30 05:00:00+00:00   97687274.0    1553292.0  187.774856
#        2025-12-31 05:00:00+00:00  120100484.0    1661178.0  188.188285
#
# [500 rows x 7 columns]
